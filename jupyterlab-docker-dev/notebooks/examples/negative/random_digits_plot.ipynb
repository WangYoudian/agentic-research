# %%
# Customize the Visualization
plt.figure(figsize=(10, 5))
plt.plot(x, random_digits, marker='o', linestyle='-', color='crimson', linewidth=2)
plt.title('Random Digits Generated with NumPy')
plt.xlabel('Index')
plt.ylabel('Digit Value')
plt.xticks(x)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Create a Plot with Matplotlib
x = np.arange(len(random_digits))
plt.figure(figsize=(10, 5))
plt.plot(x, random_digits, marker='o', linestyle='-', color='royalblue')

# Display the Plot
plt.show()

# %%
# Generate Random Digits with NumPy
# Create 30 random integers between 0 and 9
random_digits = np.random.randint(0, 10, size=30)
print(random_digits)

# %%
# Import Required Libraries
import numpy as np
import matplotlib.pyplot as plt

# Optional: set a consistent style for cleaner plots
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# # Random Digits Plot
#
# This notebook uses NumPy to generate a sequence of random digits and Matplotlib to visualize them in a simple chart.
